22%2C%22testFeedbackId%22%3A%2200000000-0000-0000-0000-000000000000%3A__EMPTY__%22%7D%2C%7B%22testName%22%3A%22filter-cleanup-test%22%2C%22testVariant%22%3A%22sorting-as-dropdown%22%2C%22testFeedbackId%22%3A%22717403e6-fe98-4d17-9208-c9f40f1232b8%3Aclientid-da264615-0823-403a-ac62-e0681c9b6146%22%7D%5D'}

response=r.get(url,headers=headers)
result=response.json()
result
# Out:
# {'total_count': 95685,
#  'pagination': {'page_count': 892, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'OY181I08E-M11',
#    'name': 'TROPICAL JUNGLE BRAZILIAN - Bas de bikini - green',
#    'price': {'original': '15,99\xa0€',
#     'promotional': '11,19\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L'],
#    'url_key': 'oysho-tropical-jungle-brazilian-bas-de-bikini-green-oy181i08e-m11',
#    'media': [{'path': 'OY/18/1I/08/EM/11/OY181I08E-M11@2.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'OY/18/1I/08/EM/11/OY181I08E-M11@12.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'OYSHO',
#    'is_premium': False,
#    'family_articles': [{'sku': 'OY181I08E-M11',
# ...

# %%
# your code here

number_of_loops=result['pagination']['page_count']
df=pd.DataFrame()
for i in range(number_of_loops):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=sale'
    response=r.get(url, headers=headers)
    result=response.json()
    flattened_data=json_normalize(result)
    flattened_data=json_normalize(flattened_data.articles[0])
    flattened_data=flattened_data.set_index('sku')
    df=df.append(flattened_data)
    if i%10==0:
        time.sleep(10)
df
# Out:
# C:\Users\anast\Anaconda3\lib\site-packages\pandas\core\frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#               amount                  brand_name  \
# sku
# UN241E0AV-Q11    NaN                Under Armour
# M3221C0L6-O11    NaN                  mint&berry
# UN241I030-Q11    NaN                Under Armour
# CO415N03F-A11    NaN                    Converse
# NI121A05R-Q11    NaN             Nike Sportswear
# NE211A094-D11    NaN                 New Balance
# CO415B09I-A11    NaN                    Converse
# NI111A0D7-B11    NaN             Nike Sportswear
# AN611E015-Q11    NaN                  Anna Field
# NI121A09O-G11    NaN             Nike Sportswear
# RE011S03V-A11    NaN              Reebok Classic
# ...

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

df.brand_name.value_counts()
# Out:
# Anna Field                  1940
# Even&Odd                    1769
# Dorothy Perkins             1142
# ONLY                        1133
# New Look                     983
# Esprit                       973
# KIOMI                        919
# mint&berry                   883
# Vero Moda                    879
# Topshop                      784
# Vila                         711
# River Island                 675
# Tamaris                      641
# PULL&BEAR                    616
# s.Oliver                     595
# TOM TAILOR                   591
# Nike Performance             583
# Next                         561
# Missguided                   555
# Puma                         546
# Tommy Hilfiger               531
# Marc O'Polo                  521
# Monki                        514
# TWINTIP                      500
# Miss Selfridge               479
# edc by Esprit                465
# Pieces                       460
# Kaffe                        444
# ...

# %%
df['price_original']=df['price.original'].str.extract('(\d+,\d*)')
df['price_promotional']=df['price.promotional'].str.extract('(\d+,\d*)')
df[['price_original','price_promotional']]
# Out:
#               price_original price_promotional
# sku
# UN241E0AV-Q11          44,95             40,00
# M3221C0L6-O11          64,95             50,00
# UN241I030-Q11          49,95             35,00
# CO415N03F-A11          69,95             55,95
# NI121A05R-Q11          24,95             20,00
# NE211A094-D11          74,95             50,00
# CO415B09I-A11          64,95             51,95
# NI111A0D7-B11         109,95             75,00
# AN611E015-Q11          39,99             39,99
# NI121A09O-G11          39,95             36,00
# RE011S03V-A11          69,95             59,45
# NI121A09Q-Q11          34,95             31,00
# PU111A0EB-Q11          60,00             25,00
# AD115B01Y-A11          99,95             80,00
# CO411A0BD-002          69,95             65,00
# AN611A0A9-Q11          31,99             19,20
# UN241G02V-Q11          69,95             56,51
# UN241D00M-Q11          24,95             21,00
# ZI111NA47-Q11         109,99             44,00
# ...

# %%
df['priceoriginal']=df['price_original'].str.replace(',','.').astype(float)
df['pricepromotional']=df['price_promotional'].str.replace(',','.').astype(float)
df[['priceoriginal','pricepromotional']]
# Out:
#                priceoriginal  pricepromotional
# sku
# UN241E0AV-Q11          44.95             40.00
# M3221C0L6-O11          64.95             50.00
# UN241I030-Q11          49.95             35.00
# CO415N03F-A11          69.95             55.95
# NI121A05R-Q11          24.95             20.00
# NE211A094-D11          74.95             50.00
# CO415B09I-A11          64.95             51.95
# NI111A0D7-B11         109.95             75.00
# AN611E015-Q11          39.99             39.99
# NI121A09O-G11          39.95             36.00
# RE011S03V-A11          69.95             59.45
# NI121A09Q-Q11          34.95             31.00
# PU111A0EB-Q11          60.00             25.00
# AD115B01Y-A11          99.95             80.00
# CO411A0BD-002          69.95             65.00
# AN611A0A9-Q11          31.99             19.20
# UN241G02V-Q11          69.95             56.51
# UN241D00M-Q11          24.95             21.00
# ZI111NA47-Q11         109.99             44.00
# ...

# %%
df['price_dif']=df['priceoriginal']-df['pricepromotional']
df['price_dif'].sort_values(ascending=False)
# Out:
# sku
# 23B21A005-J11    500.00
# PAG21C00O-J11    490.00
# IR221B006-J11    460.00
# TI821C04A-I11    453.00
# 23B21C002-A11    450.00
# MP421C014-A11    425.00
# MP421C010-Q11    425.00
# MRA21C00F-G11    425.00
# SE321U000-N11    425.00
# TI821C046-J11    408.00
# MRA21C00E-K11    405.00
# 23B21T000-G11    400.00
# PQ411B007-H11    399.95
# PQ411A004-Q12    399.95
# PQ411A004-D11    399.95
# PQ411A004-A12    399.95
# PQ411A004-D11    399.95
# 0VB21C00P-A11    398.00
# MRA21A008-Q11    398.00
# IR221B005-Q11    395.00
# TI811N009-M11    380.00
# MRA21A00B-B11    380.00
# TI821G00C-J11    380.00
# CE721C01F-Q11    379.95
# DF221C00P-G11    375.00
# MRA21J000-H11    353.00
# E2121C044-Q11    350.00
# PO221C04S-T11    350.00
# PE441E00S-K11    350.00
# PS721U00A-H11    340.00
#                   ...
# JO551Q004-D11      0.01
# BI111D00K-G11      0.01
# H0421D029-Q11      0.01
# IC221G01V-Q11      0.01
# EF329F05J-K11      0.01
# FP081A031-J13      0.01
# FP081A031-K12      0.01
# ...

# %%
df['price_dif'].sum()
# Out:
# 1912441.68
